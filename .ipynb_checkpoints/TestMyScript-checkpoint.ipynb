# %%
import pandas as pd

# Read CSV file into a DataFrame
df = pd.read_csv('/gpfs/data1/vclgp/xiongl/HeightComparisonGEDI_IS2_IS1/Out/is1_global_0dot125degree_gridded.csv')

# %%
# Display the DataFrame
print(df)
# Out:
#               x        y      layer
# 0       88.3125  75.0625   3.234000
# 1       88.3125  74.9375   3.783667
# 2       88.4375  74.9375   4.326320
# 3       88.9375  74.9375  14.455000
# 4       89.0625  74.9375  10.787000
# ...         ...      ...        ...
# 220349 -67.3125 -55.0625  11.215818
# 220350 -66.4375 -55.0625   8.573000
# 220351 -67.9375 -55.1875  15.288143
# 220352 -67.3125 -55.1875   7.076333
# 220353 -67.3125 -55.6875  13.712000
#
# [220354 rows x 3 columns]

# %%
# Loop through every row
for index, row in df.head(100).iterrows():
    # Access row values using column names or indices
    col1 = row['x']
    col2 = row['y']
    
    # Perform operations on row data
    # ...
    
    # Print row information
    print(f"Row index: {index}")
    print(f"Column 1 value: {col1}")
    print(f"Column 2 value: {col2}")
    print("")
# Out:
# Row index: 0
# Column 1 value: 88.3125
# Column 2 value: 75.0625
#
# Row index: 1
# Column 1 value: 88.3125
# Column 2 value: 74.9375
#
# Row index: 2
# Column 1 value: 88.4375
# Column 2 value: 74.9375
#
# Row index: 3
# Column 1 value: 88.9375
# Column 2 value: 74.9375
#
# Row index: 4
# Column 1 value: 89.0625
# Column 2 value: 74.9375
#
# Row index: 5
# Column 1 value: 89.1875
# Column 2 value: 74.9375
#
# Row index: 6
# Column 1 value: 89.9375
# Column 2 value: 74.9375
#
# Row index: 7
# Column 1 value: 90.5625
# Column 2 value: 74.9375
#
# Row index: 8
# Column 1 value: 90.6875
# Column 2 value: 74.9375
#
# Row index: 9
# Column 1 value: 91.0625
# Column 2 value: 74.9375
#
# Row index: 10
# Column 1 value: 91.1875
# Column 2 value: 74.9375
#
# Row index: 11
# Column 1 value: 91.5625
# Column 2 value: 74.9375
#
# Row index: 12
# Column 1 value: 92.8125
# Column 2 value: 74.9375
#
# Row index: 13
# Column 1 value: 92.9375
# Column 2 value: 74.9375
#
# Row index: 14
# ...
